# %% [markdown]
# ### 目標
# 1分足でボリンジャーバンド

# %% [markdown]
# ### インポート

# %%
# ライブラリのインポート
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mpl_finance
# %matplotlib inline
plt.rcParams['font.family'] = 'IPAPGothic'
from oandapyV20 import API
from oandapyV20.exceptions import V20Error
import oandapyV20.endpoints.instruments as instruments
import oandapyV20.endpoints.accounts as accounts
import oandapyV20.endpoints.orders as orders
import oandapyV20.endpoints.positions as positions
import oandapyV20.endpoints.pricing as pricing
from oandapyV20.endpoints.pricing import PricingInfo
import datetime
from statistics import mean
from statistics import median
import calendar
import datetime
from math import floor
import schedule
import time
import threading
import json
import random

# %%
# OANDA API v20の口座IDとAPIトークン
accountID = "101-009-12789646-001"
access_token = "1ab53171ce4413f408de6da28ea23089-6426c3d3cc947dba212b3766d1be45c6"
# OANDAのデモ口座へのAPI接続
api = API(access_token=access_token, environment="practice")

# %% [markdown]
# ### 怒濤の関数定義

# %%
# APIから取得したレートをPandasのDataFrameへ
def to_dataframe(r):
    data = []
    for raw in r.response['candles']:
        data.append([raw['time'], raw['volume'], raw['mid']['o'], raw['mid']['h'], raw['mid']['l'], raw['mid']['c']])

    # リストからPandas DataFrameへ変換
    df = pd.DataFrame(data)
    df.columns = ['Time', 'Volume', 'Open', 'High', 'Low', 'Close']
    df['Time'] = pd.to_datetime(df['Time'])
    for col in ['Open', 'High', 'Low', 'Close']:
        df[col] = df[col].apply(float)
    return df

# %%
def get_data(count, gran, year, month, day, hour, minute, second):
    # OANDA API v20の口座IDとAPIトークン
    accountID = "101-009-12789646-001"
    access_token = "1ab53171ce4413f408de6da28ea23089-6426c3d3cc947dba212b3766d1be45c6"
    # OANDAのデモ口座へのAPI接続
    api = API(access_token=access_token, environment="practice")
    fmt = '%Y-%m-%dT%H:%M:00.000000Z'
    _from = datetime.datetime(year=year, month=month, day=day,
                              hour=hour, minute=minute, second=second).strftime(fmt)
    params = {
        "count": count,
        "granularity": gran,
        'from': _from,
#         'dailyAlignment': 0
    }
    r = instruments.InstrumentsCandles(instrument="USD_JPY", params=params)
    api.request(r)
    df = to_dataframe(r)
    return df

# %%
def get_data_super(start, end, gran, sigma):
    # OANDA API v20の口座IDとAPIトークン
    accountID = "101-009-12789646-001"
    access_token = "1ab53171ce4413f408de6da28ea23089-6426c3d3cc947dba212b3766d1be45c6"
    # OANDAのデモ口座へのAPI接続
    api = API(access_token=access_token, environment="practice")
    # xxxx-xx-xx～xxxx-xx-xx の期間のデータを取得してデータフレームを返す
    s_year, s_month, s_day, s_hour, s_minute, s_second = map(int, start.split('-'))
    e_year, e_month, e_day, e_hour, e_minute, e_second = map(int, end.split('-'))
    fmt = '%Y-%m-%dT%H:%M:00.000000Z'
    from_ = datetime.datetime(year=s_year, month=s_month, day=s_day,
                              hour=s_hour, minute=s_minute, second=s_second).strftime(fmt)
    to_ = datetime.datetime(year=e_year, month=e_month, day=e_day,
                            hour=e_hour, minute=e_minute, second=e_second).strftime(fmt)
    df = pd.DataFrame()
    # 5000個制限に引っかからなければこっちの処理
    try:
        params = {
            "granularity": gran,
            'from': from_,
            'to': to_
        }
        r = instruments.InstrumentsCandles(instrument="USD_JPY", params=params)
        api.request(r)
        df = to_dataframe(r)
    # 引っかかればこっちの処理
    except:
        i = True
        while i:
            df_tmp = get_data(count=5000, gran=gran, year=s_year, month=s_month, day=s_day,
                             hour=s_hour, minute=s_minute, second=s_second)
            df = pd.concat([df, df_tmp], ignore_index=True)
            index = df_tmp.tail(1).index[0]
            s_year = df_tmp.iat[index, 0].year
            s_month = df_tmp.iat[index, 0].month
            s_day = df_tmp.iat[index, 0].day
            s_hour = df_tmp.iat[index, 0].hour
            s_minute = (df_tmp.iat[index, 0].minute + 1) % 60
            s_second = df_tmp.iat[index, 0].second
#             print('{}-{}-{}-{}-{}-{}'.format(s_year, s_month, s_day, s_hour, s_minute, s_second))
            # 5000個ずつ取得してエンド超えたら止める
            if s_year == e_year:
                i = False
        # 止めたらはみ出した分をここで切り落とす
        for i in range(len(df.index) - 5000, len(df.index)):
            if df.iat[i, 0].year == e_year and df.iat[i, 0].month == e_month and df.iat[i, 0].day == e_day:
                df = df[0:i]
                break
    # ボリンジャーバンドを追加
    df['BB20,+{}'.format(sigma)] = df['BB20,-{}'.format(sigma)] = 0
    df['BB20,+{}'.format(sigma)] = df['BB20,+{}'.format(sigma)].apply(float)
    df['BB20,-{}'.format(sigma)] = df['BB20,-{}'.format(sigma)].apply(float)
    for i in range(20, len(df)):
        df.iat[i, 6] = round(mean(df['Close'][i-20:i]) + (np.std(df['Close'][i-20:i]) * sigma), 3)
        df.iat[i, 7] = round(mean(df['Close'][i-20:i]) - (np.std(df['Close'][i-20:i]) * sigma), 3)
    # BB で参照した最初の分を落とす
    df = df[20:]
    df.reset_index(drop=True, inplace=True)
    return df

# %%
def get_evaluation(pos_df):
    # 勝率
    win_c = pos_df[pos_df['pips'] >=0].shape[0]
    WP = round(win_c / len(pos_df.index) * 100, 2)
    print('勝率: {}%'.format(WP))
    # ペイオフレシオ
    win_p = mean(pos_df[pos_df['pips'] >=0]['pips'])
    los_p = mean(pos_df[pos_df['pips'] < 0]['pips']) * (-1)
    RR = round(win_p / los_p, 4)
    print('ペイオフレシオ: {}'.format(RR))
    # 期待値
    win_pro = mean(pos_df[pos_df['pips'] >=0]['profit'])
    los_pro = mean(pos_df[pos_df['pips'] < 0]['profit']) * (-1)
    E = round(P * win_pro - pos_df[pos_df['pips'] < 0].shape[0] / len(pos_df.index) * los_pro, 2)
    print('期待値: {}円'.format(E))
    DD = round(pos_df.sort_values(by='profit', ascending=True).iat[0, 5], 2)
    print('最大ドローダウン: -{}円'.format(DD))
    return WP, RR, E, DD

# %%
def set_profit(tmp_i, i, pos, entry_rate, exit_rate, assets, df, pos_df, pos_count, lot):
    fee = 0.008
    pos_count+=1
    if pos == 'entry_long':
        pips = (exit_rate - entry_rate - fee) * 100
        l_s = 'long'
    else:
        pips = (entry_rate - exit_rate - fee) * 100
        l_s = 'short'
    profit = lot * 25 * pips / 100
    assets = round(assets + profit, 4)
    tmp_se = pd.Series( [lot, 'long', df.iat[tmp_i,0], entry_rate, df.iat[i+1,0],
                        exit_rate, pips, profit, assets ], index=pos_df.columns )
    pos_df = pos_df.append( tmp_se, ignore_index=True )
    pos = 'None'
    return assets, pos_df, pos_count, pos

# %% [markdown]
# ### バックテスト

# %%
# バックテスト
def back_test(df, seed_money, n):
    pos = 'None'
    entry_rate = 0
    pos_count = 0
    assets = seed_money
    tmp_i = 9999 # entry_date を記録する用のインデックス
    lot = 1000
    
    pos_df = pd.DataFrame(columns=['lot', 'L or S', 'entry_date', 'entry_rate', 'exit_date', 'exit_rate', 'pips', 'profit', 'assets'])

    # 実行
    for i in range(len(df.index)-1):
        next_rate = df.iat[i+1, 2] # 次の足の始値（エントリー価格）
        
        # ポジってから n分経ったら決済
        if i - tmp_i == n:
            exit_rate = next_rate
            assets, pos_df, pos_count, pos = set_profit(tmp_i, i, pos, entry_rate, exit_rate,
                                                        assets, df, pos_df, pos_count, lot)
            if assets < 0:
                break
            
        # High が BB+σ より高ければロング
        if df.iat[i, 6] < df.iat[i, 3]:
            # 逆ポジ持ってたら決済
            if pos == 'entry_short':
                assets, pos_df, pos_count, pos = set_profit(tmp_i, i, pos, entry_rate, exit_rate,
                                                            assets, df, pos_df, pos_count, lot)
                if assets < 0:
                    break
            elif pos == 'None':
                entry_rate = next_rate
                pos = 'entry_long'
                tmp_i = i+1
            
        # Low が BB-σ より低ければショート
        if df.iat[i, 7] > df.iat[i, 4]:
            # 逆ポジ持ってたら決済
            if pos == 'entry_long':
                assets, pos_df, pos_count, pos = set_profit(tmp_i, i, pos, entry_rate, exit_rate,
                                                            assets, df, pos_df, pos_count, lot)
                if assets < 0:
                    break
            elif pos == 'None':
                entry_rate = next_rate
                pos = 'entry_short'
                tmp_i = i+1
                    
    print('posision count: {}, seed_money: {}万円, assets: {}万円'.format(pos_count, seed_money/10000, round(assets/10000, 4)))
#     return pos_count, round(assets/10000, 4), pos_df
    return pos_df

# %%
# df = get_data_super(start='2018-01-01-00-00-00', end='2019-01-01-00-00-00', gran='M1', sigma=1)
pos_df = back_test(df=df, seed_money=10000000, n=19)
# Out:
# posision count: 27425, seed_money: 1000.0万円, assets: 935.5275万円

# %%
get_evaluation(pos_df)
# Out:
# 勝率: 34.28%
# ペイオフレシオ: 1.7875
# ケリー基準: 49.82%
# 期待値: 2.8円
# 最大ドローダウン: -110.91円

# %% [markdown]
# ### グラフ

# %%
pos_df['assets'].plot()

# %%
pos_df['pips'].plot()

# %%
plt.hist(pos_df['pips'], bins=100)
plt.show()

# %%
i = random.randint(0, len(df))
fig, ax = plt.subplots()
ax.plot(df['Close'][i:i+100])
ax.plot(df['BB20,+1'][i:i+100])
ax.plot(df['BB20,-1'][i:i+100])
plt.show()

# %% [markdown]
# ### チェック

# %%
pos_df.head()
# Out:
#   lot L or S                 entry_date  entry_rate  \
# 0  10   long  2013-01-02 01:21:00+00:00      86.857
# 1  10   long  2013-01-02 01:41:00+00:00      86.909
# 2  10   long  2013-01-02 02:01:00+00:00      86.948
# 3  10   long  2013-01-02 02:21:00+00:00      86.936
# 4  10   long  2013-01-02 02:41:00+00:00      87.062
#
#                    exit_date  exit_rate  pips  profit       assets
# 0  2013-01-02 01:41:00+00:00     86.909   4.4   11.00  10000011.00
# 1  2013-01-02 02:01:00+00:00     86.948   3.1    7.75  10000018.75
# 2  2013-01-02 02:21:00+00:00     86.936  -2.0   -5.00  10000013.75
# 3  2013-01-02 02:41:00+00:00     87.062  11.8   29.50  10000043.25
# 4  2013-01-02 03:01:00+00:00     87.166   9.6   24.00  10000067.25

# %%
df.head()
# Out:
#                        Time  Volume    Open    High     Low   Close  BB20,+1  \
# 0 2013-01-02 01:20:00+00:00      15  86.853  86.860  86.853  86.857   86.853
# 1 2013-01-02 01:21:00+00:00      30  86.857  86.857  86.850  86.854   86.855
# 2 2013-01-02 01:22:00+00:00      32  86.854  86.869  86.854  86.869   86.856
# 3 2013-01-02 01:23:00+00:00      39  86.871  86.882  86.871  86.880   86.860
# 4 2013-01-02 01:24:00+00:00      26  86.881  86.890  86.880  86.888   86.864
#
#    BB20,-1  Lシグナル  Sシグナル
# 0   86.803      1      0
# 1   86.809      1      0
# 2   86.809      1      0
# 3   86.812      1      0
# 4   86.814      1      0

# %%
pos_df.sort_values(by='pips').head()
# Out:
#      lot L or S                 entry_date  entry_rate  \
# 2666  10   long  2013-02-25 20:18:00+00:00      92.481
# 4546  10  short  2013-04-04 04:39:00+00:00      92.911
# 3637  10   long  2013-03-15 20:46:00+00:00      95.264
# 8294  10  short  2013-06-19 17:56:00+00:00      95.218
# 7670  10   long  2013-06-06 16:19:00+00:00      97.305
#
#                       exit_date  exit_rate   pips  profit      assets
# 2666  2013-02-25 20:38:00+00:00     91.186 -130.3 -325.75  9993474.00
# 4546  2013-04-04 04:59:00+00:00     94.092 -118.9 -297.25  9988328.50
# 3637  2013-03-17 21:05:00+00:00     94.248 -102.4 -256.00  9990702.25
# 8294  2013-06-19 18:16:00+00:00     96.154  -94.4 -236.00  9980927.50
# 7670  2013-06-06 16:39:00+00:00     96.396  -91.7 -229.25  9982219.50

# %%
# シグナル点灯のタイミングをチェック
df['Lシグナル'] = df['Sシグナル'] = 0
for i in range(len(df)):
    if df.iat[i, 6] < df.iat[i, 3]:
        df.iat[i, 8] = 1
    if df.iat[i, 7] > df.iat[i, 4]:
        df.iat[i, 9] = 1

# %%
i = 513
df[i:i+20]
# Out:
#                          Time  Volume    Open    High     Low   Close  \
# 513 2013-01-02 09:54:00+00:00      30  87.096  87.106  87.088  87.095
# 514 2013-01-02 09:55:00+00:00      12  87.098  87.098  87.090  87.092
# 515 2013-01-02 09:56:00+00:00      28  87.094  87.098  87.090  87.096
# 516 2013-01-02 09:57:00+00:00      18  87.096  87.096  87.090  87.094
# 517 2013-01-02 09:58:00+00:00      15  87.094  87.099  87.094  87.098
# 518 2013-01-02 09:59:00+00:00      15  87.098  87.100  87.093  87.093
# 519 2013-01-02 10:00:00+00:00      45  87.090  87.100  87.087  87.090
# 520 2013-01-02 10:01:00+00:00      75  87.088  87.102  87.074  87.076
# 521 2013-01-02 10:02:00+00:00      30  87.077  87.080  87.070  87.080
# 522 2013-01-02 10:03:00+00:00       5  87.080  87.080  87.078  87.079
# 523 2013-01-02 10:04:00+00:00      35  87.078  87.088  87.071  87.073
# 524 2013-01-02 10:05:00+00:00      65  87.074  87.078  87.062  87.073
# 525 2013-01-02 10:06:00+00:00     102  87.076  87.082  87.040  87.045
# 526 2013-01-02 10:07:00+00:00      43  87.048  87.074  87.048  87.070
# 527 2013-01-02 10:08:00+00:00      24  87.070  87.077  87.068  87.068
# 528 2013-01-02 10:09:00+00:00      37  87.068  87.078  87.064  87.068
# 529 2013-01-02 10:10:00+00:00      21  87.070  87.074  87.064  87.070
# 530 2013-01-02 10:11:00+00:00      16  87.070  87.076  87.065  87.074
# 531 2013-01-02 10:12:00+00:00       9  87.074  87.074  87.068  87.068
# 532 2013-01-02 10:13:00+00:00      15  87.068  87.084  87.068  87.084
#
#      BB20,+1  BB20,-1  Lシグナル  Sシグナル
# 513   87.102   87.075      1      0
# 514   87.102   87.078      0      0
# 515   87.103   87.078      0      0
# 516   87.103   87.078      0      0
# 517   87.103   87.079      0      0
# 518   87.103   87.079      0      0
# 519   87.102   87.079      0      0
# 520   87.100   87.079      1      1
# 521   87.097   87.078      0      1
# 522   87.095   87.077      0      0
# 523   87.094   87.077      0      1
# 524   87.094   87.075      0      1
# 525   87.094   87.075      0      1
# 526   87.096   87.072      0      1
# 527   87.096   87.071      0      1
# 528   87.095   87.070      0      1
# 529   87.095   87.068      0      1
# 530   87.094   87.068      0      1
# 531   87.094   87.068      0      0
# 532   87.093   87.066      0      0

# %%
df.shape
# Out:
# (371427, 10)

# %% [markdown]
# ### 1年間で検証

# %%
p_s_n = pd.DataFrame(columns=['period', 'sigma', 'n', 'pos_count', 'assets', '勝率', 'ペイオフレシオ',
                              'ケリー基準', '期待値', '最大ドローダウン'])
for p in range(10, 18+1):
    period = '20{}'.format(p)
    start = '20{}-01-01-00-00-00'.format(p)
    end = '20{}-01-01-00-00-00'.format(p+1)
    for s in range(1, 5+1):
        df = get_data_super(start=start, end=end, gran='M1', sigma=s)
        for n in range(10, 35+1):
            pos_count, assets, pos_df = back_test(df=df, seed_money=10000000, n=n)
            WP, RR, KLY, E, DD = get_evaluation(pos_df)
            print('period: {}, sigma: {}, n: {}, pos_count: {}, assets: {}万円'.format(period, s, n, pos_count, assets))
            tmp_se = pd.Series([period, s, n, pos_count, assets, WP, RR, KLY, E, DD], index=p_s_n.columns)
            p_s_n = p_s_n.append(tmp_se, ignore_index=True)
# Out:
# period: 2010, sigma: 1, n: 10, pos_count: 62241, assets: 5480.375万円
# period: 2010, sigma: 1, n: 11, pos_count: 57792, assets: 5831.8425万円
# period: 2010, sigma: 1, n: 12, pos_count: 54243, assets: 6230.78万円
# period: 2010, sigma: 1, n: 13, pos_count: 51174, assets: 6453.9425万円
# period: 2010, sigma: 1, n: 14, pos_count: 48429, assets: 6653.405万円
# period: 2010, sigma: 1, n: 15, pos_count: 46045, assets: 6866.37万円
# period: 2010, sigma: 1, n: 16, pos_count: 43916, assets: 7043.8125万円
# period: 2010, sigma: 1, n: 17, pos_count: 41955, assets: 7135.2075万円
# period: 2010, sigma: 1, n: 18, pos_count: 40185, assets: 7221.92万円
# period: 2010, sigma: 1, n: 19, pos_count: 38534, assets: 7264.7875万円
# period: 2013, sigma: 1, n: 29, pos_count: 30479, assets: 6112.5875万円
# period: 2013, sigma: 1, n: 30, pos_count: 29978, assets: 5980.975万円
# period: 2013, sigma: 1, n: 31, pos_count: 29469, assets: 5797.8625万円
# period: 2013, sigma: 1, n: 32, pos_count: 29014, assets: 5505.8375万円
# period: 2013, sigma: 1, n: 33, pos_count: 28598, assets: 5292.1675万円
# period: 2013, sigma: 1, n: 34, pos_count: 28214, assets: 5145.925万円
# period: 2013, sigma: 1, n: 35, pos_count: 27836, assets: 4938.3075万円
# period: 2013, sigma: 2, n: 10, pos_count: 42149, assets: 1645.12万円
# period: 2013, sigma: 2, n: 11, pos_count: 40140, assets: 2011.17万円
# period: 2013, sigma: 2, n: 12, pos_count: 38452, assets: 2447.965万円
# period: 2013, sigma: 2, n: 13, pos_count: 36931, assets: 2769.285万円
# period: 2013, sigma: 2, n: 14, pos_count: 35631, assets: 3073.2225万円
# period: 2013, sigma: 2, n: 15, pos_count: 34368, assets: 3496.86万円
# period: 2013, sigma: 2, n: 16, pos_count: 33193, assets: 3879.805万円
# period: 2013, sigma: 2, n: 17, pos_count: 31998, assets: 4177.8025万円
# period: 2013, sigma: 2, n: 18, pos_count: 30874, assets: 4551.175万円
# period: 2013, sigma: 2, n: 19, pos_count: 29695, assets: 4878.3825万円
# period: 2013, sigma: 2, n: 20, pos_count: 28462, assets: 5104.265万円
# period: 2013, sigma: 2, n: 21, pos_count: 27425, assets: 5384.92万円
# period: 2013, sigma: 2, n: 22, pos_count: 26507, assets: 5461.7625万円
# period: 2013, sigma: 2, n: 23, pos_count: 25648, assets: 5575.58万円
# period: 2013, sigma: 2, n: 24, pos_count: 24870, assets: 5615.1125万円
# period: 2013, sigma: 2, n: 25, pos_count: 24152, assets: 5651.9075万円
# period: 2013, sigma: 2, n: 26, pos_count: 23476, assets: 5659.015万円
# period: 2013, sigma: 2, n: 27, pos_count: 22860, assets: 5700.83万円
# period: 2013, sigma: 2, n: 28, pos_count: 22272, assets: 5674.72万円
# period: 2013, sigma: 2, n: 29, pos_count: 21745, assets: 5703.4825万円
# period: 2013, sigma: 2, n: 30, pos_count: 21195, assets: 5697.61万円
# period: 2013, sigma: 2, n: 31, pos_count: 20770, assets: 5678.905万円
# period: 2013, sigma: 2, n: 32, pos_count: 20356, assets: 5654.7025万円
# period: 2013, sigma: 2, n: 33, pos_count: 19936, assets: 5619.8625万円
# period: 2013, sigma: 2, n: 34, pos_count: 19549, assets: 5534.12万円
# period: 2013, sigma: 2, n: 35, pos_count: 19151, assets: 5429.4225万円
# period: 2013, sigma: 3, n: 10, pos_count: 23894, assets: 532.6225万円
# period: 2013, sigma: 3, n: 11, pos_count: 23568, assets: 480.235万円
# period: 2013, sigma: 3, n: 12, pos_count: 23181, assets: 591.7125万円
# period: 2013, sigma: 3, n: 13, pos_count: 22854, assets: 633.505万円
# period: 2013, sigma: 3, n: 14, pos_count: 22494, assets: 817.7万円
# period: 2013, sigma: 3, n: 15, pos_count: 22161, assets: 924.805万円
# period: 2013, sigma: 3, n: 16, pos_count: 21819, assets: 1023.3775万円
# period: 2013, sigma: 3, n: 17, pos_count: 21463, assets: 1186.9875万円
# period: 2013, sigma: 3, n: 18, pos_count: 21063, assets: 1323.935万円
# period: 2013, sigma: 3, n: 19, pos_count: 20637, assets: 1550.8725万円
# period: 2013, sigma: 3, n: 20, pos_count: 20156, assets: 1735.3575万円
# period: 2013, sigma: 3, n: 21, pos_count: 19669, assets: 1938.085万円
# period: 2013, sigma: 3, n: 22, pos_count: 19241, assets: 2047.06万円
# period: 2013, sigma: 3, n: 23, pos_count: 18860, assets: 2208.4025万円
# period: 2013, sigma: 3, n: 24, pos_count: 18438, assets: 2339.3575万円
# period: 2013, sigma: 3, n: 25, pos_count: 18033, assets: 2486.43万円
# period: 2013, sigma: 3, n: 26, pos_count: 17645, assets: 2635.0675万円
# period: 2013, sigma: 3, n: 27, pos_count: 17273, assets: 2771.35万円
# period: 2013, sigma: 3, n: 28, pos_count: 16928, assets: 2844.155万円
# period: 2013, sigma: 3, n: 29, pos_count: 16590, assets: 2933.38万円
# period: 2013, sigma: 3, n: 30, pos_count: 16258, assets: 2974.62万円
# period: 2013, sigma: 3, n: 31, pos_count: 15944, assets: 3092.45万円
# period: 2013, sigma: 3, n: 32, pos_count: 15629, assets: 3144.6575万円
# period: 2013, sigma: 3, n: 33, pos_count: 15375, assets: 3180.9275万円
# period: 2013, sigma: 3, n: 34, pos_count: 15105, assets: 3218.38万円
# period: 2013, sigma: 3, n: 35, pos_count: 14831, assets: 3255.47万円
# period: 2013, sigma: 4, n: 10, pos_count: 11431, assets: 580.7975万円
# period: 2013, sigma: 4, n: 11, pos_count: 11398, assets: 539.275万円
# period: 2013, sigma: 4, n: 12, pos_count: 11330, assets: 549.755万円
# period: 2013, sigma: 4, n: 13, pos_count: 11276, assets: 532.5225万円
# period: 2013, sigma: 4, n: 14, pos_count: 11229, assets: 593.275万円
# period: 2013, sigma: 4, n: 15, pos_count: 11166, assets: 641.135万円
# period: 2013, sigma: 4, n: 16, pos_count: 11120, assets: 646.4725万円
# period: 2013, sigma: 4, n: 17, pos_count: 11066, assets: 716.2775万円
# period: 2013, sigma: 4, n: 18, pos_count: 10986, assets: 751.3475万円
# period: 2013, sigma: 4, n: 19, pos_count: 10893, assets: 781.18万円
# period: 2013, sigma: 4, n: 20, pos_count: 10765, assets: 871.5275万円
# period: 2013, sigma: 4, n: 21, pos_count: 10653, assets: 895.96万円
# period: 2013, sigma: 4, n: 22, pos_count: 10514, assets: 949.0175万円
# period: 2013, sigma: 4, n: 23, pos_count: 10407, assets: 973.6925万円
# period: 2013, sigma: 4, n: 24, pos_count: 10266, assets: 993.21万円
# period: 2013, sigma: 4, n: 25, pos_count: 10144, assets: 1066.265万円
# period: 2013, sigma: 4, n: 26, pos_count: 10042, assets: 1032.6万円
# period: 2013, sigma: 4, n: 27, pos_count: 9917, assets: 1108.98万円
# period: 2013, sigma: 4, n: 28, pos_count: 9812, assets: 1112.5575万円
# period: 2013, sigma: 4, n: 29, pos_count: 9707, assets: 1195.805万円
# period: 2013, sigma: 4, n: 30, pos_count: 9587, assets: 1205.94万円
# period: 2013, sigma: 4, n: 31, pos_count: 9469, assets: 1225.465万円
# period: 2013, sigma: 4, n: 32, pos_count: 9364, assets: 1255.6325万円
# period: 2013, sigma: 4, n: 33, pos_count: 9263, assets: 1310.0425万円
# period: 2013, sigma: 4, n: 34, pos_count: 9166, assets: 1316.3925万円
# period: 2013, sigma: 4, n: 35, pos_count: 9067, assets: 1346.3275万円
# period: 2013, sigma: 5, n: 10, pos_count: 5270, assets: 736.065万円
# period: 2013, sigma: 5, n: 11, pos_count: 5269, assets: 742.915万円
# period: 2013, sigma: 5, n: 12, pos_count: 5248, assets: 703.055万円
# period: 2013, sigma: 5, n: 13, pos_count: 5233, assets: 678.4225万円
# period: 2013, sigma: 5, n: 14, pos_count: 5224, assets: 727.535万円
# period: 2013, sigma: 5, n: 15, pos_count: 5218, assets: 746.765万円
# period: 2013, sigma: 5, n: 16, pos_count: 5210, assets: 751.24万円
# period: 2013, sigma: 5, n: 17, pos_count: 5192, assets: 769.3575万円
# period: 2013, sigma: 5, n: 18, pos_count: 5179, assets: 785.85万円
# period: 2013, sigma: 5, n: 19, pos_count: 5164, assets: 792.5225万円
# period: 2013, sigma: 5, n: 20, pos_count: 5136, assets: 804.84万円
# period: 2013, sigma: 5, n: 21, pos_count: 5109, assets: 800.345万円
# period: 2013, sigma: 5, n: 22, pos_count: 5082, assets: 809.4925万円
# period: 2013, sigma: 5, n: 23, pos_count: 5055, assets: 829.135万円
# period: 2013, sigma: 5, n: 24, pos_count: 5014, assets: 825.885万円
# period: 2013, sigma: 5, n: 25, pos_count: 4989, assets: 824.7525万円
# period: 2013, sigma: 5, n: 26, pos_count: 4958, assets: 794.5575万円
# period: 2013, sigma: 5, n: 27, pos_count: 4925, assets: 816.085万円
# period: 2013, sigma: 5, n: 28, pos_count: 4902, assets: 809.8625万円
# period: 2013, sigma: 5, n: 29, pos_count: 4889, assets: 855.98万円
# period: 2013, sigma: 5, n: 30, pos_count: 4862, assets: 827.8325万円
# period: 2013, sigma: 5, n: 31, pos_count: 4841, assets: 782.5875万円
# period: 2013, sigma: 5, n: 32, pos_count: 4819, assets: 815.8675万円
# period: 2013, sigma: 5, n: 33, pos_count: 4799, assets: 871.6575万円
# period: 2013, sigma: 5, n: 34, pos_count: 4767, assets: 858.64万円
# period: 2013, sigma: 5, n: 35, pos_count: 4740, assets: 869.58万円
# period: 2014, sigma: 1, n: 10, pos_count: 61872, assets: 3876.8025万円
# period: 2014, sigma: 1, n: 11, pos_count: 57551, assets: 4232.3975万円
# period: 2014, sigma: 1, n: 12, pos_count: 53995, assets: 4546.6425万円
# period: 2014, sigma: 1, n: 13, pos_count: 50947, assets: 4832.2475万円
# period: 2014, sigma: 1, n: 14, pos_count: 48257, assets: 4951.5025万円
# period: 2014, sigma: 1, n: 15, pos_count: 45877, assets: 5105.07万円
# period: 2014, sigma: 1, n: 16, pos_count: 43699, assets: 5224.5275万円
# period: 2014, sigma: 1, n: 17, pos_count: 41799, assets: 5314.3525万円
# period: 2014, sigma: 1, n: 18, pos_count: 40063, assets: 5442.08万円
# period: 2014, sigma: 1, n: 19, pos_count: 38433, assets: 5522.14万円
# period: 2014, sigma: 1, n: 20, pos_count: 36953, assets: 5481.125万円
# period: 2014, sigma: 1, n: 21, pos_count: 35724, assets: 5399.9325万円
# period: 2014, sigma: 1, n: 22, pos_count: 34631, assets: 5327.705万円
# period: 2014, sigma: 1, n: 23, pos_count: 33636, assets: 5229.6475万円
# period: 2014, sigma: 1, n: 24, pos_count: 32774, assets: 5123.8225万円
# period: 2014, sigma: 1, n: 25, pos_count: 31961, assets: 5001.72万円
# period: 2014, sigma: 1, n: 26, pos_count: 31201, assets: 4852.17万円
# period: 2014, sigma: 1, n: 27, pos_count: 30528, assets: 4731.8775万円
# period: 2014, sigma: 1, n: 28, pos_count: 29901, assets: 4636.355万円
# period: 2014, sigma: 1, n: 29, pos_count: 29344, assets: 4533.1175万円
# period: 2014, sigma: 1, n: 30, pos_count: 28816, assets: 4433.9275万円
# period: 2014, sigma: 1, n: 31, pos_count: 28308, assets: 4310.5万円
# period: 2014, sigma: 1, n: 32, pos_count: 27851, assets: 4158.58万円
# period: 2014, sigma: 1, n: 33, pos_count: 27436, assets: 4002.165万円
# period: 2014, sigma: 1, n: 34, pos_count: 27066, assets: 3873.005万円
# period: 2014, sigma: 1, n: 35, pos_count: 26715, assets: 3727.475万円
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-308-49563e382260> in <module>
#       6     end = '20{}-01-01-00-00-00'.format(p+1)
#       7     for s in range(1, 5+1):
# ----> 8         df = get_data_super(start=start, end=end, gran='M1', sigma=s)
#       9         for n in range(10, 35+1):
#      10             pos_count, assets, pos_df = back_test(df=df, seed_money=10000000, n=n)
#
# <ipython-input-271-4e06c2c6e1dd> in get_data_super(start, end, gran, sigma)
#      53     for i in range(20, len(df)):
#      54         df.iat[i, 6] = round(mean(df['Close'][i-20:i]) + (np.std(df['Close'][i-20:i]) * sigma), 3)
# ---> 55         df.iat[i, 7] = round(mean(df['Close'][i-20:i]) - (np.std(df['Close'][i-20:i]) * sigma), 3)
#      56     # BB で参照した最初の分を落とす
#      57     df = df[20:]
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in std(a, axis, dtype, out, ddof, keepdims)
#    3237             pass
#    3238         else:
# -> 3239             return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#    3240
#    3241     return _methods._std(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#   10974                                       skipna=skipna, ddof=ddof)
#   10975         return self._reduce(f, name, axis=axis, numeric_only=numeric_only,
# > 10976                             skipna=skipna, ddof=ddof)
#   10977
#   10978     return set_function_name(stat_func, name, cls)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3628                                           'numeric_only.'.format(name))
#    3629             with np.errstate(all='ignore'):
# -> 3630                 return op(delegate, skipna=skipna, **kwds)
#    3631
#    3632         # TODO(EA) dispatch to Index
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     118                 if (_USE_BOTTLENECK and skipna and
#     119                         _bn_ok_dtype(values.dtype, bn_name)):
# --> 120                     result = bn_func(values, axis=axis, **kwds)
#     121
#     122                     # prefer to treat inf/-inf as NA, but must compute the func
#
# KeyboardInterrupt:
