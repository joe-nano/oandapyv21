# %% [markdown]
# # 指値厚いとこのちょい前に指し太郎

# %%
import datetime
from math import floor
import pprint
import schedule
from statistics import mean
from statistics import median
from statistics import StatisticsError
import sys
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.family'] = 'IPAPGothic'
from oandapyV20 import API
from oandapyV20.exceptions import V20Error
import oandapyV20.endpoints.instruments as instruments
import oandapyV20.endpoints.accounts as accounts
import oandapyV20.endpoints.orders as orders
import oandapyV20.endpoints.positions as positions
import oandapyV20.endpoints.pricing as pricing
from oandapyV20.endpoints.pricing import PricingInfo
from oandapyV20.contrib.requests import (MarketOrderRequest, StopLossDetails)
import oandapyV20.endpoints.forexlabs as labs

sys.path.append('../')
from oandapyV21 import *

# OANDA API v20の口座IDとAPIトークン(房林蛇ver)
accountID = "101-009-13234797-001"
access_token = "9739ebcc49088322e07e334ad3697b04-16314025c95d08a3d40882b027316211"

# %%
def get_orderbook(date='', inst='USD_JPY'):
    api = API(access_token=access_token, environment="practice")
    if date != '':
        year, month, day, hour, minute, second = map(int, date.split('-'))
        fmt = '%Y-%m-%dT%H:%M:00.000000Z'
        time = datetime.datetime(year=year, month=month, day=day,
                                  hour=hour, minute=minute, second=second).strftime(fmt)
        params = {
            'time': time,
        }
        r = instruments.InstrumentsOrderBook(instrument=inst, params=params)
    else:
        r = instruments.InstrumentsOrderBook(instrument=inst)
    api.request(r)
    return r

# %%
r = get_orderbook(inst='USD_JPY')
buckets = r.response['orderBook']['buckets']
price = []
long = []
short = []
for i in range(len(buckets)):
    price.extend([buckets[i]['price']])
    long.extend([float(buckets[i]['longCountPercent'])])
    short.extend([float(buckets[i]['shortCountPercent'])])
order_df = pd.DataFrame(columns=['price', 'long_percent', 'short_percent'],
                        data={'price': price, 'long_percent': long, 'short_percent': short})

# %%
order_df.sort_values(by='long_percent', ascending=False).head(10)
# Out:
#          price  long_percent  short_percent
# 667    109.700        2.3135         0.1151
# 182     54.900        0.7328         0.0000
# 668    109.750        0.6480         0.5814
# 0        0.000        0.5875         0.0121
# 639    108.300        0.4845         0.1393
# 523    102.500        0.4784         0.0242
# 753    114.000        0.4421         0.1696
# 1341  1300.000        0.4179         0.0000
# 666    109.650        0.3755         0.1575
# 623    107.500        0.3634         0.1090

# %%
order_df.sort_values(by='short_percent', ascending=False).head(10)
# Out:
#         price  long_percent  short_percent
# 1030  131.000        0.0000         6.0380
# 669   109.800        0.1877         5.3234
# 674   110.050        0.1635         1.6594
# 673   110.000        0.3391         1.5201
# 677   110.200        0.1332         1.5141
# 672   109.950        0.2241         1.4777
# 678   110.250        0.1332         1.4414
# 675   110.100        0.1938         0.8115
# 676   110.150        0.1817         0.7994
# 721   112.400        0.0303         0.7631

# %%
order_df.tail()

# %%
r = get_orderbook(inst='GBP_USD')
r.response
# Out:
# {'orderBook': {'instrument': 'GBP_USD',
#   'time': '2020-02-05T14:00:00Z',
#   'unixTime': '1580911200',
#   'price': '1.30092',
#   'bucketWidth': '0.00050',
#   'buckets': [{'price': '0.00000',
#     'longCountPercent': '0.1447',
#     'shortCountPercent': '0.0814'},
#    {'price': '0.00050',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.00100',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.00150',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.00200',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.00250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.00300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.00350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.00400',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.00600',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.00650',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.00950',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.01000',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.01100',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.01200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.01250',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.01350',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.02000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.02200',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.03000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.03550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.04000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.05000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.08000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.08900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.10000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '0.15000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.20000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.20550',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.21000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.21250',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.23000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.24000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.24750',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.25000',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.25300',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.25550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.27500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.28850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.28950',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.29250',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.29600',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.29650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.30000',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.30300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.32800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.34550',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.37600',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.40000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.40450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.47650',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.49850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.50000',
#     'longCountPercent': '0.0814',
#     'shortCountPercent': '0.0543'},
#    {'price': '0.50400',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.55000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.56250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.59050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.60000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.62000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.62100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.62600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.62750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.64500',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.64900',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.65000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.65100',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.65200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.65450',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.65500',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.66750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.68550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.68950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.71500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.71950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.72050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.72150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.72850',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.73900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.74000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75650',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.77550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.77700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.77750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.77950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.78000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.78500',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.79150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.80000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.80550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.81000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0452'},
#    {'price': '0.81900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.83300',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.84750',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.85850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.85900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.87950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.89500',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.89550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '0.89700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.89950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90000',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90450',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90500',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91450',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.91900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92000',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92500',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.92650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.92900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.93950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.94050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.94150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.94200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.94300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.94350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.94450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.94550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.94600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.94650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.94700',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.94800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.94850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.94950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.95200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.95450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.95850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.95950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.96000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.96100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.96200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.96250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.96350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.96450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.96500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.96600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.96650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.96750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.96850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.96900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.97000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.97050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.97100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.97150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.97250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.97300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.97350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.97400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.97450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.97500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.97600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.97650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.97700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.97750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.97800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.97850',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.97900',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.97950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.98000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.98050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.98100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.98150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.98250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.98300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.98400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.98500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0271'},
#    {'price': '0.98550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.98600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.98650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.98700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '0.98750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.98800',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.98900',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.98950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.99300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0271'},
#    {'price': '0.99400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '0.99550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99700',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99850',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.99950',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.00000',
#     'longCountPercent': '0.6423',
#     'shortCountPercent': '1.0223'},
#    {'price': '1.00050',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00150',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.00950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.01250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01550',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01700',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01750',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01800',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.01850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.01950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.02200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.02350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02450',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.02500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02700',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02750',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.02850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.02950',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.03250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03300',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03450',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03550',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03700',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03800',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03900',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.03950',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04000',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04300',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04400',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04550',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.04950',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.05050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.05300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05400',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.05950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.06050',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06150',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06750',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.06950',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.07050',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07100',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07150',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.07400',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07550',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07650',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07750',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.07900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.07950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.08000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.08400',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.08600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.08650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08850',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08900',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.08950',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.09550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.09700',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09750',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.09900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.09950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.10000',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0995'},
#    {'price': '1.10050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10300',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.10650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.10750',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.10950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11100',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.11200',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11300',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11400',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.11500',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11550',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.11700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11750',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11800',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11900',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.11950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.12000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.12050',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.12200',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12250',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12350',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.12550',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12850',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.12900',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.12950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.13100',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.13200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.13250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13300',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.13500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.13600',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.13900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.13950',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.14000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.14100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.14150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.14250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.14300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.14350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.14400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.14450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.14500',
#     'longCountPercent': '0.0271',
# ...
#    {'price': '1.31600',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0995'},
#    {'price': '1.31650',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.31700',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.31750',
#     'longCountPercent': '0.1809',
#     'shortCountPercent': '0.1176'},
#    {'price': '1.31800',
#     'longCountPercent': '0.2443',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.31850',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.1086'},
#    {'price': '1.31900',
#     'longCountPercent': '0.0814',
#     'shortCountPercent': '0.0995'},
#    {'price': '1.31950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.1447'},
#    {'price': '1.32000',
#     'longCountPercent': '0.0995',
#     'shortCountPercent': '0.2804'},
#    {'price': '1.32050',
#     'longCountPercent': '0.1447',
#     'shortCountPercent': '0.1447'},
#    {'price': '1.32100',
#     'longCountPercent': '0.2081',
#     'shortCountPercent': '0.2714'},
#    {'price': '1.32150',
#     'longCountPercent': '0.1357',
#     'shortCountPercent': '0.1357'},
#    {'price': '1.32200',
#     'longCountPercent': '0.0814',
#     'shortCountPercent': '0.0995'},
#    {'price': '1.32250',
#     'longCountPercent': '0.0905',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.32300',
#     'longCountPercent': '0.0995',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.32350',
#     'longCountPercent': '0.1357',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.32400',
#     'longCountPercent': '0.0905',
#     'shortCountPercent': '0.0995'},
#    {'price': '1.32450',
#     'longCountPercent': '0.0995',
#     'shortCountPercent': '0.1176'},
#    {'price': '1.32500',
#     'longCountPercent': '0.0724',
#     'shortCountPercent': '0.1447'},
#    {'price': '1.32550',
#     'longCountPercent': '0.0814',
#     'shortCountPercent': '0.1176'},
#    {'price': '1.32600',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.32650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.32700',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0905'},
#    {'price': '1.32750',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.2443'},
#    {'price': '1.32800',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.1086'},
#    {'price': '1.32850',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0905'},
#    {'price': '1.32900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.32950',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.33000',
#     'longCountPercent': '0.1086',
#     'shortCountPercent': '0.1357'},
#    {'price': '1.33050',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.33100',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.33150',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.1086'},
#    {'price': '1.33200',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.3619'},
#    {'price': '1.33250',
#     'longCountPercent': '0.0724',
#     'shortCountPercent': '0.1357'},
#    {'price': '1.33300',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.1086'},
#    {'price': '1.33350',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.33400',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.1176'},
#    {'price': '1.33450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.33500',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0905'},
#    {'price': '1.33550',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.1176'},
#    {'price': '1.33600',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0905'},
#    {'price': '1.33650',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.1086'},
#    {'price': '1.33700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.33750',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.1176'},
#    {'price': '1.33800',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.33850',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0995'},
#    {'price': '1.33900',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.33950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.34000',
#     'longCountPercent': '0.1086',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.34050',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.34100',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.34150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.34200',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.34250',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.34300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.34350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.34400',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.34450',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.34500',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.34550',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.34600',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.34650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.34700',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.34750',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.34800',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.34850',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.34900',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.34950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.35000',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.1357'},
#    {'price': '1.35050',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.35100',
#     'longCountPercent': '0.0724',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.35150',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.35200',
#     'longCountPercent': '0.0724',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.35250',
#     'longCountPercent': '0.0905',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.35300',
#     'longCountPercent': '0.0995',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.35350',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.35400',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.35450',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.35500',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.1086'},
#    {'price': '1.35550',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.35600',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.35650',
#     'longCountPercent': '0.0814',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.35700',
#     'longCountPercent': '0.0814',
#     'shortCountPercent': '0.1176'},
#    {'price': '1.35750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.35800',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.35850',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.35900',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.35950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.36000',
#     'longCountPercent': '0.0724',
#     'shortCountPercent': '0.1267'},
#    {'price': '1.36050',
#     'longCountPercent': '0.0724',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.36100',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.1176'},
#    {'price': '1.36150',
#     'longCountPercent': '0.1176',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.36200',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.36250',
#     'longCountPercent': '0.0905',
#     'shortCountPercent': '0.0905'},
#    {'price': '1.36300',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.36350',
#     'longCountPercent': '0.0724',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.36400',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.1538'},
#    {'price': '1.36450',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.36500',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.36550',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.36600',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.36650',
#     'longCountPercent': '0.0995',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.36700',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.36750',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.36800',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.1628'},
#    {'price': '1.36850',
#     'longCountPercent': '0.0633',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.36900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.36950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.37000',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.2533'},
#    {'price': '1.37050',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.37100',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.37150',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.37200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.37250',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.37300',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.37350',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.37400',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.37450',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.37500',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.1267'},
#    {'price': '1.37550',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.37600',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.37650',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0905'},
#    {'price': '1.37700',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.37750',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.37800',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.37850',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.37900',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.37950',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.38000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.1086'},
#    {'price': '1.38050',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.38100',
#     'longCountPercent': '0.0543',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.38150',
#     'longCountPercent': '0.0452',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.38200',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.38250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.38300',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.38350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.38400',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.38450',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.38500',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0724'},
#    {'price': '1.38550',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.38600',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.38650',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.38700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.38750',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.38800',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.38850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.38900',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.38950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.39000',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.39050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.39100',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0181'},
#    {'price': '1.39150',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.39200',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.39250',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.39300',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.39400',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.39450',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0633'},
#    {'price': '1.39550',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.39600',
#     'longCountPercent': '0.0362',
#     'shortCountPercent': '0.0090'},
#    {'price': '1.39650',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.39700',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0543'},
#    {'price': '1.39750',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.39800',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.39900',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.39950',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.40000',
#     'longCountPercent': '0.0271',
#     'shortCountPercent': '0.0814'},
#    {'price': '1.40050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0452'},
#    {'price': '1.40100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0362'},
#    {'price': '1.40150',
#     'longCountPercent': '0.0181',
#     'shortCountPercent': '0.0271'},
#    {'price': '1.40200',
#     'longCountPercent': '0.0090',
#     'shortCountPercent': '0.0724'},
#    ...]}}

# %%
# ==============================================================================
# brief        オープンオーダー、オープンポジションの描写
#
# author       たっきん
#
# 事前準備 :
#     oandapyV20のインストール (pip install oandapyV20)
#     Bokehのインストール（conda install bokeh）
# ==============================================================================

import copy
import datetime
from bokeh.plotting import figure, show
from oandapyV20 import API
from bokeh.layouts import gridplot
from datetime import timedelta

from bokehlib import bokeh_common as bc
from fxx import oanda_common as oc
from fxx import your_account as ya
import oandapyV20.endpoints.instruments as instruments
import pandas as pd


class OrderBook(object):
    """ OrderBook - オーダーブック定義クラス。"""

    def __init__(self, granularity):
        """"コンストラクタ"""

        self.__BUCKETS = "buckets"

        self.__ORD_BOOK = "orderBook"
        self.__PSI_BOOK = "positionBook"
        self.__PRICE = "price"
        self.__LONG = "longCountPercent"
        self.__SHORT = "shortCountPercent"

        self.__TIME = "time"
        self.__CUR_PRICE = "price"
        self.__BUCKET_WIDTH = "bucketWidth"

        self.__WIDE = 12 * 60 * 60 * 1000  # half day in ms
        self.__WIDE_SCALE = 0.2

        self.__DT_FMT = "%Y-%m-%dT%H:%M:00Z"
        self.__GRANULARITY = granularity

        self.__CUT_TH = 50  # 現レートから上下何本残すか
        self.__X_AXIS_MAX = 2.5  # X軸レンジ

        self.__BG_COLOR = "#2e2e2e"
        self.__BAR_R_COLOR = "#00A4BD"
        self.__BAR_L_COLOR = "#FF8400"
        self.__CURPRI_COLOR = "#7DA900"

        self.__ord_df = []
        self.__ord_curpri = 0

        self.__psi_df = []
        self.__psi_curpri = 0

        self.__api = api

    def getInstrumentsOrderBook(self, instrument, dt):

        params = {
            "time": dt.strftime(self.__DT_FMT),
        }

        # APIへ過去データをリクエスト
        ic = instruments.InstrumentsOrderBook(instrument=instrument,
                                              params=params)
        self.__api.request(ic)

        self.__data = []
        for raw in ic.response[self.__ORD_BOOK][self.__BUCKETS]:
            self.__data.append([float(raw[self.__PRICE]),
                                float(raw[self.__LONG]),
                                float(raw[self.__SHORT])])

        # リストからデータフレームへ変換
        df = pd.DataFrame(self.__data)
        df.columns = [self.__PRICE,
                      self.__LONG,
                      self.__SHORT]
        df = df.set_index(self.__PRICE).sort_index(ascending=False)
        # date型を整形する
        time = pd.to_datetime(self.__changeDateTimeFmt(
            ic.response[self.__ORD_BOOK][self.__TIME]))
        cur_price = float(ic.response[self.__ORD_BOOK][self.__CUR_PRICE])
        bucket_width = float(ic.response[self.__ORD_BOOK][self.__BUCKET_WIDTH])

        print(df)
        print(bucket_width)

        print(time)
        print(cur_price)
        idx_th = bucket_width * self.__CUT_TH
        self.__ord_df = df[(df.index > cur_price - idx_th)
                           & (df.index < cur_price + idx_th)]
        self.__ord_curpri = cur_price

    def getInstrumentsPositionBook(self, instrument, dt):

        params = {
            "time": dt.strftime(self.__DT_FMT),
        }

        # APIへ過去データをリクエスト
        ic = instruments.InstrumentsPositionBook(instrument=instrument,
                                                 params=params)
        self.__api.request(ic)

        self.__data = []
        for raw in ic.response[self.__PSI_BOOK][self.__BUCKETS]:
            self.__data.append([float(raw[self.__PRICE]),
                                float(raw[self.__LONG]),
                                float(raw[self.__SHORT])])

        # リストからデータフレームへ変換
        df = pd.DataFrame(self.__data)
        df.columns = [self.__PRICE,
                      self.__LONG,
                      self.__SHORT]
        df = df.set_index(self.__PRICE).sort_index(ascending=False)
        # date型を整形する
        time = pd.to_datetime(self.__changeDateTimeFmt(
            ic.response[self.__PSI_BOOK][self.__TIME]))
        cur_price = float(ic.response[self.__PSI_BOOK][self.__CUR_PRICE])
        bucket_width = float(ic.response[self.__PSI_BOOK][self.__BUCKET_WIDTH])

        print(df)
        print(bucket_width)

        print(time)
        print(cur_price)
        idx_th = bucket_width * self.__CUT_TH
        self.__psi_df = df[(df.index > cur_price - idx_th)
                           & (df.index < cur_price + idx_th)]
        self.__psi_curpri = cur_price

    def drawPositionOrderBook(self, fig_width=500):

        set_tools = bc.ToolType.gen_str(bc.ToolType.XPAN,
                                        bc.ToolType.WHEEL_ZOOM,
                                        bc.ToolType.BOX_ZOOM,
                                        bc.ToolType.RESET,
                                        bc.ToolType.SAVE)

        df = copy.copy(self.__ord_df)
        # --------------- メインfigure ---------------
        plt1 = figure(
            plot_height=fig_width,
            plot_width=fig_width,
            x_range=(-self.__X_AXIS_MAX, self.__X_AXIS_MAX),
            tools=set_tools,
            title="Order Book example",
            background_fill_color=self.__BG_COLOR
        )
        plt1.grid.grid_line_alpha = 0.3

        df_up = df[self.__LONG][(df.index > self.__ord_curpri)]
        df_lo = -df[self.__SHORT][(df.index < self.__ord_curpri)]
        df_right = pd.concat([df_up, df_lo])

        df_up = -df[self.__SHORT][(df.index > self.__ord_curpri)]
        df_lo = df[self.__LONG][(df.index < self.__ord_curpri)]
        df_left = pd.concat([df_up, df_lo])

        plt1.hbar(y=df.index, height=0.03, left=df_right,
                  right=0, color=self.__BAR_R_COLOR)
        plt1.hbar(y=df.index, height=0.03, left=df_left,
                  right=0, color=self.__BAR_L_COLOR)
        plt1.line(x=[-self.__X_AXIS_MAX, self.__X_AXIS_MAX],
                  y=[self.__ord_curpri, self.__ord_curpri],
                  color=self.__CURPRI_COLOR, line_width=3)

        plt1.xaxis.axis_label = "Count Percent[%]"
        plt1.yaxis.axis_label = "Price"

        df = copy.copy(self.__psi_df)
        # --------------- メインfigure ---------------
        plt2 = figure(
            plot_height=fig_width,
            plot_width=fig_width,
            x_range=(-self.__X_AXIS_MAX, self.__X_AXIS_MAX),
            tools=set_tools,
            title="Position Book example",
            background_fill_color=self.__BG_COLOR
        )
        plt2.grid.grid_line_alpha = 0.3

        df_up = df[self.__LONG][(df.index > self.__psi_curpri)]
        df_lo = -df[self.__SHORT][(df.index < self.__psi_curpri)]
        df_right = pd.concat([df_up, df_lo])

        df_up = -df[self.__SHORT][(df.index > self.__psi_curpri)]
        df_lo = df[self.__LONG][(df.index < self.__psi_curpri)]
        df_left = pd.concat([df_up, df_lo])

        plt2.hbar(y=df.index, height=0.03, left=df_right,
                  right=0, color=self.__BAR_R_COLOR)
        plt2.hbar(y=df.index, height=0.03, left=df_left,
                  right=0, color=self.__BAR_L_COLOR)
        plt2.line(x=[-self.__X_AXIS_MAX, self.__X_AXIS_MAX],
                  y=[self.__psi_curpri, self.__psi_curpri],
                  color=self.__CURPRI_COLOR, line_width=3)

        plt2.xaxis.axis_label = "Count Percent[%]"
        plt2.yaxis.axis_label = "Price"

        # make a grid
        grid = gridplot([[plt1, plt2]])

        show(grid)

    def __changeDateTimeFmt(self, dt):
        """"日付フォーマットの変換メソッド
        引数:
            dt (str): DT_FMT形式でフォーマットされた日付
        戻り値:
            tf_dt (str): 変換後の日付
        """
        tdt = datetime.datetime.strptime(dt, self.__DT_FMT)

        return tdt

# %%
if True:
    cs = OrderBook(oc.OandaGrn.D)

    instrument = oc.OandaIns.USD_JPY

    dt = datetime.datetime(year=2019, month=5, day=18,
                           hour=21, minute=40, second=0)
    dttk = dt - timedelta(hours=9)

    cs.getInstrumentsOrderBook(instrument, dttk)
    cs.getInstrumentsPositionBook(instrument, dttk)
    cs.drawPositionOrderBook(500)
# Out:
#               longCountPercent  shortCountPercent
# price
# 9.223372e+15            0.0000             0.0229
# 1.000000e+08            0.0000             0.0076
# 2.489500e+06            0.0076             0.0000
# 1.000022e+06            0.0000             0.0076
# 1.000000e+06            0.0076             0.0153
# 1.261690e+05            0.0076             0.0000
# 1.230560e+05            0.0000             0.0076
# 1.133000e+05            0.0000             0.0076
# 1.126600e+05            0.0076             0.0000
# 1.113690e+05            0.0000             0.0076
# 1.102710e+05            0.0000             0.0076
# 1.098170e+05            0.0000             0.0076
# 1.095220e+05            0.0000             0.0076
# 1.001110e+05            0.0000             0.0076
# 1.000000e+05            0.0000             0.0153
# 7.020000e+04            0.0000             0.0076
# 5.000000e+04            0.0000             0.0153
# 1.999995e+04            0.0000             0.0076
# 1.500000e+04            0.0000             0.0153
# 1.200000e+04            0.0000             0.0076
# 1.111185e+04            0.0000             0.0076
# 1.090900e+04            0.0000             0.0076
# 1.087800e+04            0.0000             0.0076
# 1.073000e+04            0.0000             0.0076
# 1.055000e+04            0.0000             0.0076
# 1.000000e+04            0.0000             0.0535
# 9.000000e+03            0.0000             0.0076
# 8.000000e+03            0.0000             0.0076
# 6.295000e+03            0.0000             0.0076
# 5.443000e+03            0.0000             0.0076
# ...                        ...                ...
# 2.100000e+00            0.0000             0.0076
# 2.000000e+00            0.0076             0.0306
# 1.900000e+00            0.0000             0.0076
# 1.800000e+00            0.0000             0.0076
# 1.750000e+00            0.0153             0.0000
# 1.700000e+00            0.0000             0.0076
# 1.600000e+00            0.0000             0.0076
# 1.500000e+00            0.0000             0.0076
# 1.400000e+00            0.0000             0.0076
# 1.350000e+00            0.0000             0.0076
# 1.300000e+00            0.0000             0.0076
# 1.200000e+00            0.0076             0.0076
# 1.150000e+00            0.0076             0.0000
# 1.100000e+00            0.0306             0.0153
# 1.050000e+00            0.0000             0.0076
# 1.000000e+00            0.3362             0.0917
# 9.500000e-01            0.0000             0.0076
# 9.000000e-01            0.0000             0.0153
# 8.500000e-01            0.0000             0.0076
# 8.000000e-01            0.0076             0.0076
# 7.000000e-01            0.0229             0.0076
# 6.000000e-01            0.0000             0.0076
# 5.000000e-01            0.0076             0.0076
# 4.000000e-01            0.0000             0.0076
# 3.000000e-01            0.0000             0.0229
# 2.500000e-01            0.0000             0.0153
# 2.000000e-01            0.0000             0.0076
# 1.500000e-01            0.0076             0.0000
# 1.000000e-01            0.0229             0.0306
# 0.000000e+00            0.0306             0.0000
#
# [1292 rows x 2 columns]
# 0.05
# 2019-05-18 12:40:00
# 110.074
#         longCountPercent  shortCountPercent
# price
# 123.40            0.0060             0.0121
# 123.35            0.0060             0.0000
# 123.25            0.0060             0.0121
# 123.20            0.0060             0.0060
# 123.15            0.0121             0.0060
# 123.10            0.0060             0.0060
# 123.00            0.0060             0.0000
# 122.95            0.0000             0.0121
# 122.90            0.0060             0.0121
# 122.85            0.0000             0.0181
# 122.80            0.0121             0.0000
# 122.75            0.0121             0.0121
# 122.70            0.0060             0.0000
# 122.60            0.0060             0.0000
# 122.45            0.0060             0.0000
# 122.40            0.0000             0.0121
# 122.05            0.0060             0.0000
# 121.95            0.0060             0.0000
# 121.85            0.0060             0.0000
# 121.80            0.0060             0.0000
# 121.70            0.0060             0.0000
# 121.65            0.0000             0.0060
# 121.60            0.0060             0.0000
# 121.35            0.0060             0.0000
# 121.30            0.0060             0.0060
# 121.25            0.0181             0.0000
# 121.20            0.0060             0.0060
# 121.10            0.0060             0.0000
# 121.05            0.0000             0.0181
# 121.00            0.0060             0.0121
# ...                  ...                ...
# 101.40            0.0121             0.0181
# 101.35            0.0181             0.0121
# 101.30            0.0422             0.0181
# 101.25            0.0121             0.0181
# 101.20            0.0302             0.0121
# 101.15            0.0060             0.0121
# 101.10            0.0483             0.0060
# 101.05            0.0483             0.0060
# 101.00            0.0060             0.0422
# 100.95            0.0121             0.0302
# 100.90            0.0000             0.0060
# 100.85            0.0121             0.0000
# 100.80            0.0121             0.0121
# 100.75            0.0362             0.0121
# 100.70            0.0603             0.0241
# 100.65            0.0302             0.0000
# 100.60            0.0241             0.0241
# 100.55            0.0422             0.0422
# 100.50            0.0121             0.0060
# 100.45            0.0362             0.0121
# 100.40            0.0422             0.0000
# 100.35            0.0241             0.0121
# 100.30            0.0302             0.0000
# 100.25            0.0121             0.0181
# 100.20            0.0060             0.0000
# 100.15            0.0422             0.0060
# 100.00            0.0060             0.0000
# 99.95             0.0060             0.0060
# 99.85             0.0000             0.0060
# 99.60             0.0060             0.0000
#
# [425 rows x 2 columns]
# 0.05
# 2019-05-18 12:40:00
# 110.074
